# %%
#imports
import pandas as pd
import matplotlib.pyplot as plt

# %%
# importing dataset
dt = pd.read_csv("../dataset/ks-projects-201801.csv", usecols = [6,8,10,12,13,14])
dt.head(10)
# Out:
#        goal   pledged  backers  usd pledged  usd_pledged_real  usd_goal_real
# 0    1000.0      0.00        0         0.00              0.00        1533.95
# 1   30000.0   2421.00       15       100.00           2421.00       30000.00
# 2   45000.0    220.00        3       220.00            220.00       45000.00
# 3    5000.0      1.00        1         1.00              1.00        5000.00
# 4   19500.0   1283.00       14      1283.00           1283.00       19500.00
# 5   50000.0  52375.00      224     52375.00          52375.00       50000.00
# 6    1000.0   1205.00       16      1205.00           1205.00        1000.00
# 7   25000.0    453.00       40       453.00            453.00       25000.00
# 8  125000.0   8233.00       58      8233.00           8233.00      125000.00
# 9   65000.0   6240.57       43      6240.57           6240.57       65000.00

# %% [markdown]
# ### Columns such has pledged, usd pledged, usd_pledged_real, usd_goal_real are need to scale down.
# * Currently choosing

# %%
dt.corr()
# Out:
#                       goal   pledged   backers  usd pledged  usd_pledged_real  \
# goal              1.000000  0.007358  0.004012     0.005534          0.005104
# pledged           0.007358  1.000000  0.717079     0.857370          0.952843
# backers           0.004012  0.717079  1.000000     0.697426          0.752539
# usd pledged       0.005534  0.857370  0.697426     1.000000          0.907743
# usd_pledged_real  0.005104  0.952843  0.752539     0.907743          1.000000
# usd_goal_real     0.942692  0.005024  0.004517     0.006172          0.005596
#
#                   usd_goal_real
# goal                   0.942692
# pledged                0.005024
# backers                0.004517
# usd pledged            0.006172
# usd_pledged_real       0.005596
# usd_goal_real          1.000000

# %% [markdown]
# # Standardization

# %% [markdown]
# ### Using StandardScaler

# %%
# Fit the data and transfrom it

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

scaler.fit(dt)
dt_transfrom = scaler.transform(dt)

# %%
dt_transfrom = pd.DataFrame(dt_transfrom, columns = dt.columns) # numpy to dataframe

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

axes[0].scatter(dt["usd_pledged_real"], dt['usd_goal_real'], label="Before")
axes[0].legend()

axes[1].scatter(dt_transfrom["usd_pledged_real"], dt_transfrom['usd_goal_real'], label="After")
axes[1].legend()

plt.tight_layout()
fig.suptitle("StandardScaler")
plt.show()

# %% [markdown]
# # Normalization

# %% [markdown]
# ### Using MinMaxScaling

# %%
# Fit the data and transfrom it

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

scaler.fit(dt)
dt_transfrom = scaler.transform(dt)

# %%
dt_transfrom = pd.DataFrame(dt_transfrom, columns = dt.columns) # numpy to dataframe

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

axes[0].scatter(dt["usd_pledged_real"], dt['usd_goal_real'], label="Before")
axes[0].legend()

axes[1].scatter(dt_transfrom["usd_pledged_real"], dt_transfrom['usd_goal_real'], label="After")
axes[1].legend()

plt.tight_layout()
fig.suptitle("MinMaxScaler")
plt.show()

# %% [markdown]
# ### Using Mean scaling

# %%
# Fit the data and transfrom it

from sklearn.preprocessing import MaxAbsScaler
scaler = MaxAbsScaler()

scaler.fit(dt)
dt_transfrom = scaler.transform(dt)

# %%
dt_transfrom = pd.DataFrame(dt_transfrom, columns = dt.columns) # numpy to dataframe

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

axes[0].scatter(dt["usd_pledged_real"], dt['usd_goal_real'], label="Before")
axes[0].legend()

axes[1].scatter(dt_transfrom["usd_pledged_real"], dt_transfrom['usd_goal_real'], label="After")
axes[1].legend()

plt.tight_layout()
fig.suptitle("MaxAbsScaler")
plt.show()

# %% [markdown]
# ### Using Robust scaling

# %%
# Fit the data and transfrom it

from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()

scaler.fit(dt)
dt_transfrom = scaler.transform(dt)

# %%
dt_transfrom = pd.DataFrame(dt_transfrom, columns = dt.columns) # numpy to dataframe

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))  # 1 row, 2 columns

axes[0].scatter(dt["usd_pledged_real"], dt['usd_goal_real'], label="Before")
axes[0].legend()

axes[1].scatter(dt_transfrom["usd_pledged_real"], dt_transfrom['usd_goal_real'], label="After")
axes[1].legend()

plt.tight_layout()
fig.suptitle("RobustScaler")
plt.show()
